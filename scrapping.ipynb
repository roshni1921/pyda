# %%
from dputils.scrape import Tag, Scraper

# %% [markdown]
# - Tag class helps to decide what to collect from the page.
# - Scraper executes the scraping process.

# %%
url ="https://www.amazon.in/s?k=laptop&crid=EDRQEB13J40U&sprefix=laptop%2Caps%2C245&ref=nb_sb_noss_1"

# %%
amazon=Scraper(url)
# Out:
# Selecting a random User-Agent...
# Randomly picked browser: Firefox
# Randomly picked operating system: Linux
# 🌐🌐🌐🌐🌐🌐🌐🌐🌐🌐
# User agent:  {'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:94.0) Gecko/20100101 Firefox/94.0'}
# Cookies:  {'session-id': '', 'session-id-time': '', 'session-token': ''}
# url:  https://www.amazon.in/s?k=laptop&crid=EDRQEB13J40U&sprefix=laptop%2Caps%2C245&ref=nb_sb_noss_1
# 🌐🌐🌐🌐🌐🌐🌐🌐🌐🌐

# %%
target=Tag(cls='s-main-slot s-result-list s-search-results sg-row')
items=Tag(cls='s-result-item')
title=Tag('h2',cls='a-size-mini a-spacing-none a-color-base s-line-clamp-2')
price=Tag('span',cls='a-price')

# %%
result=amazon.get_repeating_page_data(target,items,heading=title,price=price)

# %%
import pandas as pd

# %%
df=pd.DataFrame(result)
df
# Out:
#                                               heading           price
# 0                                                None            None
# 1                                                None            None
# 2   (Refurbished) Lenovo ThinkPad 6th Gen Intel Co...  ₹17,249₹17,249
# 3   (Refurbished) Lenovo ThinkPad 5th Gen Intel Co...  ₹14,999₹14,999
# 4   Lenovo V15 Intel Celeron N4500 15.6" (39.62 cm...  ₹21,990₹21,990
# 5                                                None  ₹35,990₹35,990
# 6                                                None  ₹35,990₹35,990
# 7                                                None  ₹36,990₹36,990
# 8                                                None  ₹47,990₹47,990
# 9                                                None  ₹54,990₹54,990
# 10                                               None  ₹69,990₹69,990
# 11                                               None  ₹16,990₹16,990
# 12                                               None            None
# 13  ASUS VivoBook 15 (2021) Thin and Light Laptop,...  ₹19,990₹19,990
# 14  ASUS Vivobook Go 14 (2023), 14" (35.56 cm) FHD...  ₹22,990₹22,990
# 15  (Refurbished) HP Chromebook 13 G1 6th Gen Inte...  ₹12,999₹12,999
# 16  Dell 14 Thin & Light Laptop, 12th Gen Intel Co...  ₹34,990₹34,990
# 17  Acer Aspire Lite 12th Gen Intel Core i3-1215U ...  ₹31,999₹31,999
# 18  HP Laptop 15s, 12th Gen Intel Core i3, 15.6-in...  ₹39,600₹39,600
# 19  HP Laptop 15s, AMD Ryzen 3 5300U, 15.6-inch (3...  ₹31,990₹31,990
# 20  Lenovo IdeaPad 1 AMD Ryzen 5 5500U 15.6" HD Th...  ₹38,990₹38,990
# 21  HP Laptop 15s, 12th Gen Intel Core i5-1235U, 1...  ₹52,990₹52,990
# 22  Dell [Smartchoice 15 Thin & Light Laptop, 12th...  ₹36,990₹36,990
# 23  (Refurbished) HP C640 10th Gen Intel Core i5 T...  ₹17,499₹17,499
# 24  ASUS Vivobook 15, Intel Celeron N4020, 15.6" (...  ₹26,990₹26,990
# 25  Apple MacBook Air Laptop M1 chip, 13.3-inch/33...  ₹71,990₹71,990
# 26                                               None        ₹749₹749
# 27                                               None            None
# 28                                               None            None
# 29                                               None            None
# 30                                               None            None
# 31                                               None            None
